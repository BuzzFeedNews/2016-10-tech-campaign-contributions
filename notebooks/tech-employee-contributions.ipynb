# %% [markdown]
# # Analyzing Tech Employees' Donations To The Clinton and Trump Campaigns
#
# Please see the [main page](https://github.com/BuzzFeedNews/2016-10-tech-employee-contributions) for details.

# %% [markdown]
# ## Load the data

# %%
import pandas as pd
import glob
import re

# %% [markdown]
# ### Load contributions

# %%
MAIN_COLUMNS = [
    "filer_committee_id_number", "form_type",  "transaction_id", "contribution_date",
    "contributor_last_name", "contributor_first_name", "contributor_middle_name",
    "contributor_city", "contributor_state", "contributor_employer", 
    "contribution_amount", "contribution_aggregate",
    "contribution_purpose_descrip", "memo_code", "memo_text_description"
]

# %%
def read_individual_contributions(path):
    df = pd.read_csv(path, low_memory=False)
    df["contributor_employer"] = df["contributor_employer"].fillna("").str.strip().str.upper()
    return df[df["entity_type"] == "IND"][MAIN_COLUMNS]

# %%
sa17a_files = glob.glob("../data/contributions/*/*-SA17A-*.csv")
sa18_files = glob.glob("../data/contributions/*/*-SA18-*.csv")

# %%
contributions = pd.concat([ read_individual_contributions(path)
    for path in (sa17a_files + sa18_files) ])

# %%
# Assign committee names to committee IDs
contributions["committee"] = contributions["filer_committee_id_number"].apply({
    "C00580100": "Donald J. Trump For President",
    "C00575795": "Hillary For America"
}.get)

# %%
contributions.head().T
# Out:
#                                                      0                    1  \
# filer_committee_id_number                    C00575795            C00575795
# form_type                                        SA17A                SA17A
# transaction_id                                      C5                   C2
# contribution_date                          2.01504e+07          2.01504e+07
# contributor_last_name                        McAuliffe            McAuliffe
# contributor_first_name                         Terence              Dorothy
# contributor_middle_name                             R.                   S.
# contributor_city                               Mc Lean              Mc Lean
# contributor_state                                   VA                   VA
# contributor_employer          COMMONWEALTH OF VIRGINIA
# contribution_amount                               2700                 2700
# contribution_aggregate                            2700                 2700
# contribution_purpose_descrip                       NaN                  NaN
# memo_code                                          NaN                  NaN
# memo_text_description                              NaN                  NaN
# committee                          Hillary For America  Hillary For America
#
#                                                 2                      3  \
# filer_committee_id_number               C00575795              C00575795
# form_type                                   SA17A                  SA17A
# transaction_id                               C947                C183810
# contribution_date                     2.01504e+07            2.01506e+07
# contributor_last_name                     Gensler                Macchio
# contributor_first_name                       Gary                 Steven
# contributor_middle_name                       NaN                    NaN
# contributor_city                   Brooklandville              Dix Hills
# contributor_state                              MD                     NY
# contributor_employer          HILLARY FOR AMERICA  CLEARFLO TECHNOLOGIES
# contribution_amount                          2700                   2700
# contribution_aggregate                       2700                   2700
# contribution_purpose_descrip                  NaN                    NaN
# memo_code                                     NaN                    NaN
# memo_text_description                         NaN                    NaN
# committee                     Hillary For America    Hillary For America
#
#                                                 4
# filer_committee_id_number               C00575795
# form_type                                   SA17A
# transaction_id                            C135530
# contribution_date                     2.01505e+07
# contributor_last_name                      Benson
# contributor_first_name                    Barbara
# contributor_middle_name                       NaN
# contributor_city                       Cordillera
# contributor_state                              CO
# contributor_employer
# contribution_amount                          1000
# contribution_aggregate                       1000
# contribution_purpose_descrip                  NaN
# memo_code                                     NaN
# memo_text_description                         NaN
# committee                     Hillary For America

# %% [markdown]
# Millions of dollars received from direct, *itemized* individual contributions (SA17A) and transfers from other authorized committees (SA18):

# %%
(contributions.groupby([
    "form_type", "committee"
])["contribution_amount"].sum().unstack().fillna(0) / 1e6).round(1)
# Out:
#            Donald J. Trump For President  Hillary For America
# form_type
# SA17A                               33.2                249.7
# SA18                                42.7                103.8

# %% [markdown]
# ## Identify contributions from major technology companies
#
# The code below identifies alternative spellings and aliases for 20 major technology companies. For each company, we include "matching" patterns and anti-matching patterns (i.e., similar company names to exclude, e.g., "Amazon Consulting").

# %%
employers = [
    ("Adobe", re.compile(r"^ADOBE$|ADOBE, INC|ADOBE SYSTEMS"), None),
    ("Airbnb", re.compile(r"AIRBNB"), re.compile(r"UBER")), # Ignore Uber
    ("Amazon", re.compile(r"AMAZON\b"), re.compile(r"AMAZON CONSULTING|AMAZON PRODUCE|AMAZON INDUSTRIES")), # Ignore Amazon Consulting/Produce/etc.
    ("Apple", re.compile(r"^APPLE$|^APPLE,? INC|\bAPPLE TECH"), None),
    ("Box", re.compile(r"^BOX, INC|^BOX$"), None),
    ("Cisco", re.compile(r"^CISCO,? INC|^CISCO$|^CISCO SYSTEMS"), None),
    ("Dell", re.compile(r"^DELL,? INC|^DELL$|^DELL COMPUTER|^DELL SOFTWARE|^DELL SERVICES"), None),
    ("Ebay", re.compile(r"^EBAY\b"), None),
    ("Facebook", re.compile(r"^FACEBOOK"), None),
    ("Google/Alphabet", re.compile(r"\bGOOGLE|ALPHABET"), re.compile(r"ALPHABET ENERGY|HCL AMERICA|BY PPC")), # Ignore Alphabet Energy, HCL America, PPC
    ("Hewlett-Packard", re.compile(r"HEWLETT.PACKARD|\bHP,? INC|\bHP ENTERPRISE|\bHP LABS"), re.compile(r"EXPERIS")), # Ignore Experis
    ("IBM", re.compile(r"^IBM|\bIBM CO"), None),
    ("Intel", re.compile(r"^INTEL CORP|^INTEL,? INC|^INTEL$"), None),
    ("Microsoft", re.compile(r"MICROSOFT"), None),
    ("Netflix", re.compile(r"NETFLIX"), None),
    ("Oracle", re.compile(r"\bORACLE\b"), re.compile(r"ORACLE LENS")),
    ("Salesforce", re.compile(r"SALESFORCE"), None),
    ("Square", re.compile(r"^SQUARE$|^SQUARE,? INC"), None),
    ("Twitter", re.compile(r"\bTWITTER\b"), None),
    ("Uber", re.compile(r"\bUBER\b"), re.compile(r"DRIVER|PARTNER|AIRBNB|LYFT|NURSECORE|INDEPENDENT|4 SEASONS")), # Ignore seeming contractors
]

# %%
contributions["meta_employer"] = None
for name, pat, anti_pat in employers:
    contributions.loc[
        (contributions["contributor_employer"].apply(lambda x: re.search(pat, x) != None)) &
        (contributions["contributor_employer"].apply(lambda x: re.search(anti_pat, x) == None) if anti_pat else True) &
        ~(contributions["contributor_employer"].str.contains("CONTRACTOR"))
    , "meta_employer"] = name

# %%
tech_contributions = contributions[
    contributions["meta_employer"].notnull()
]
tech_contributions.head().T
# Out:
#                                               48                   72   \
# filer_committee_id_number               C00575795            C00575795
# form_type                                   SA17A                SA17A
# transaction_id                            C181210               C47640
# contribution_date                     2.01505e+07          2.01504e+07
# contributor_last_name                       Burns               Thomas
# contributor_first_name                     Bonnie              Kristin
# contributor_middle_name                       NaN                  NaN
# contributor_city                           Rincon             Tega Cay
# contributor_state                              GA                   SC
# contributor_employer                          IBM            MICROSOFT
# contribution_amount                        158.92                   50
# contribution_aggregate                     208.92                  277
# contribution_purpose_descrip                  NaN                  NaN
# memo_code                                     NaN                  NaN
# memo_text_description                         NaN                  NaN
# committee                     Hillary For America  Hillary For America
# meta_employer                                 IBM            Microsoft
#
#                                               80                   96   \
# filer_committee_id_number               C00575795            C00575795
# form_type                                   SA17A                SA17A
# transaction_id                            C197930              C178000
# contribution_date                     2.01506e+07          2.01505e+07
# contributor_last_name                 Windsheimer               Martin
# contributor_first_name                      Marci              Brendon
# contributor_middle_name                       NaN                  NaN
# contributor_city                    San Francisco           Villa Park
# contributor_state                              CA                   IL
# contributor_employer                   APPLE INC.               GOOGLE
# contribution_amount                        200.12                   10
# contribution_aggregate                    1480.82                 2710
# contribution_purpose_descrip                  NaN                  NaN
# memo_code                                     NaN                  NaN
# memo_text_description                         NaN                  NaN
# committee                     Hillary For America  Hillary For America
# meta_employer                               Apple      Google/Alphabet
#
#                                               200
# filer_committee_id_number               C00575795
# form_type                                   SA17A
# transaction_id                             C58630
# contribution_date                     2.01504e+07
# contributor_last_name                      Fuller
# contributor_first_name                Jacquelline
# contributor_middle_name                       NaN
# contributor_city                           Orinda
# contributor_state                              CA
# contributor_employer                       GOOGLE
# contribution_amount                          2700
# contribution_aggregate                       2700
# contribution_purpose_descrip                  NaN
# memo_code                                     NaN
# memo_text_description                         NaN
# committee                     Hillary For America
# meta_employer                     Google/Alphabet

# %% [markdown]
# ## Group contributions by employer

# %% [markdown]
# - `itemized_contributions` counts only the itemized contributions listing the employer
# - `sum_max_agg` tries to infer the total (including non-itemized contributions), based on the maximum `contribution_aggregate` field for each first-name/last-name/employer combination. This approach isn't foolproof but should, generally, provide an upper-bound estimate for contributions.

# %%
tech_contributions_by_employer = pd.DataFrame({
    "itemized_contributions": tech_contributions\
        .groupby([ "meta_employer", "committee" ])["contribution_amount"].sum(),
    "sum_max_agg": tech_contributions.groupby([
        "meta_employer", "committee",
        "contributor_first_name", "contributor_last_name"
    ])["contribution_aggregate"].max().reset_index()\
        .groupby([ "meta_employer", "committee" ])["contribution_aggregate"].sum()
})
tech_contributions_by_employer
# Out:
#                                                itemized_contributions  \
# meta_employer   committee
# Adobe           Donald J. Trump For President                 1082.40
#                 Hillary For America                          68245.01
# Airbnb          Hillary For America                          42723.21
# Hillary For America                        4439969.79   4768564.27

# %% [markdown]
# ---
#
# # Rough estimate of companies whose employees have donated the most to each campaign
#
# Note: The numbers below are meant only as rough estimates. They do not, for example, attempt to merge sibling/parent companies or misspellings.

# %% [markdown]
# ### Take basic steps to normalize employer names
#
# - Remove "LLC", "INC", "INCORPORATED", "CO", "LLP", etc. endings.
# - Convert all letters to lowercase.
# - Convert all non-letters into underscores.

# %%
import namestand

# %%
cruft_pat = re.compile(r",? (LLC|INC|INCORPORATED|CORPORATION|COROPRATION|CORPRATION|CORP|CO|LLP)$")

# %%
def normalize_name(name):
    stripped = re.sub(cruft_pat, "", name.strip().strip("."))
    return namestand.downscore(stripped).strip("_")

# %%
contributions["employer_norm"] = contributions["contributor_employer"].apply(normalize_name)

# %%
grp_employer_norm = contributions.groupby([ "committee", "employer_norm" ])
by_employer_norm = pd.DataFrame({
    "amount": grp_employer_norm["contribution_amount"].sum(),
    "spellings": grp_employer_norm["contributor_employer"].apply(lambda x: " • ".join(sorted(x.unique())))
}).sort_values("amount", ascending=False)

# %% [markdown]
# ### Hillary For America

# %%
top_employers_clinton = by_employer_norm.loc["Hillary For America"].head(50)
top_employers_clinton
# Out:
#                                               amount  \
# employer_norm
#                                      71763838.339991
# self_employed                        48686372.559995
# retired                              13971228.140001
# information_requested                13712874.950000
# not_employed                          2991814.180000
# google                                1088767.920000
# none                                   784280.900000
# morgan_morgan                          574091.250000
# microsoft                              550750.330000
# stanford_university                    513289.570000
# apple                                  502624.970000
# u_s_government                         488365.230000
# harvard_university                     432143.720000
# morgan_stanley                         395147.130000
# u_s_department_of_state                391759.790000
# dla_piper                              357266.750000
# columbia_university                    354627.500000
# facebook                               351010.380000
# jpmorgan_chase                         321762.720000
# paul_weiss_rifkind_wharton_garrison    318533.310000
# skadden_arps_slate_meagher_flom        317298.500000
# latham_watkins                         312769.950000
# new_york_university                    310674.760000
# kirkland_ellis                         308882.130000
# akin_gump_strauss_hauer_feld           308486.390000
# sidley_austin                          299642.910000
# kaiser_permanente                      288764.350000
# covington_burling                      288125.730000
# sullivan_cromwell                      274902.820000
# yale_university                        274155.040000
# ibm                                    273018.210000
# university_of_california               271360.590000
# salesforce_com                         266323.050000
# u_s_department_of_justice              266059.360000
# hogan_lovells                          263515.120000
# wells_fargo                            262740.820000
# at_t                                   248732.890000
# state_of_california                    248567.860000
# arnold_porter                          246577.170000
# goldman_sachs                          246567.160000
# wilmerhale                             240375.180000
# creative_artists_agency                239910.300000
# bank_of_america                        234484.710000
# greenberg_traurig                      230488.660000
# simpson_thacher_bartlett               229250.080000
# amazon_com                             223234.640000
# dish_network                           215235.430000
# corning                                210881.290000
# georgetown_university                  203958.010000
# ucla                                   203388.710000
#
#                                                                              spellings
# employer_norm
#                                       • - • -- • --- • ----- • --------------------...
# self_employed                        SELF  EMPLOYED • SELF EMPLOYED • SELF- EMPLOYE...
# wilmerhale                               WILMERHALE • WILMERHALE LLP • WILMERHALE, LLP
# creative_artists_agency                                        CREATIVE ARTISTS AGENCY
# bank_of_america                                                        BANK OF AMERICA
# greenberg_traurig                    GREENBERG TRAURIG • GREENBERG TRAURIG LLP • GR...
# simpson_thacher_bartlett             SIMPSON THACHER & BARTLETT LLP • SIMPSON THACH...
# amazon_com                           AMAZON.COM • AMAZON.COM INC • AMAZON.COM, INC ...
# dish_network                                           DISH NETWORK • DISH NETWORK LLC
# corning                              CORNING • CORNING INC. • CORNING INCORPORATED ...
# georgetown_university                                            GEORGETOWN UNIVERSITY
# ucla                                                                      UCLA • UCLA`

# %% [markdown]
# ### Donald J. Trump For President

# %%
top_employers_trump = by_employer_norm.loc["Donald J. Trump For President"].head(50)
top_employers_trump
# Out:
#                                    amount  \
# employer_norm
# retired                       23378013.69
# self_employed                 10175872.46
# information_requested          9007485.82
# homemaker                      1304884.20
# self                            175356.10
# boch_automotive_group            86936.80
# not_employed                     84234.93
# owner                            61314.79
# alliance_coal                    46080.00
# murray_energy                    43384.85
#                                  40041.84
# american_airlines                37824.78
# jennmar                          34080.00
# merrill_lynch                    32611.81
# student                          32450.85
# entrepreneur                     31299.30
# not_specified                    28922.20
# colony_capital                   26600.00
# microsoft                        25610.78
# northrop_grumman                 25515.74
# ibm                              24210.56
# xpo_logistics                    24000.01
# us_army                          23611.28
# lockheed_martin                  23377.82
# southwest_airlines               22066.44
# wells_fargo_advisors             22023.16
# none                             21566.60
# nucor                            20940.00
# wells_fargo                      20510.49
# me                               20378.20
# united_airlines                  20303.60
# at_t                             20195.40
# donald_j_trump_for_president     20085.86
# american_energy                  20056.60
# google                           19497.00
# business_owner                   18995.17
# morgan_stanley                   18985.24
# america_s_catch                  18900.00
# twenty_one_twelve                18255.90
# coldwell_banker                  18181.43
# cisco_systems                    17756.45
# us_navy                          17756.24
# walmart                          17507.65
# bank_of_america                  17027.39
# usaf                             16775.84
# centaur_gaming                   16411.50
# boeing                           16365.01
# usps                             16284.51
# veg_fresh_farms                  16200.00
# dod                              15395.13
#
#                                                                       spellings
# employer_norm
# retired                                                      RETIRED • RETIRED.
# self_employed                 SELF  -  EMPLOYED • SELF - EMPLOYED • SELF -EM...
# information_requested                                     INFORMATION REQUESTED
# homemaker                                                             HOMEMAKER
# self                                                            SELF • SELF LLC
# boch_automotive_group                                     BOCH AUTOMOTIVE GROUP
# not_employed                                                       NOT EMPLOYED
# owner                                                                     OWNER
# alliance_coal                 ALLIANCE COAL • ALLIANCE COAL LLC • ALLIANCE C...
# murray_energy                 MURRAY ENERGY • MURRAY ENERGY CORP • MURRAY EN...
#
# american_airlines                                             AMERICAN AIRLINES
# jennmar                                           JENNMAR • JENNMAR CORPORATION
# merrill_lynch                 MERRILL - LYNCH • MERRILL LYNCH • MERRILL LYNC...
# student                                                                 STUDENT
# entrepreneur                                                       ENTREPRENEUR
# not_specified                                                     NOT SPECIFIED
# colony_capital                             COLONY CAPITAL • COLONY CAPITAL, INC
# microsoft                     MICROSOFT • MICROSOFT CORP • MICROSOFT CORPORA...
# northrop_grumman              NORTHROP GRUMMAN • NORTHROP GRUMMAN CORP • NOR...
# ibm                           IBM • IBM CORP • IBM CORPORATION • IBM CORPRAT...
# xpo_logistics                 XPO  LOGISTICS • XPO LOGISTICS • XPO LOGISTICS...
# us_army                                                                 US ARMY
# lockheed_martin               LOCKHEED MARTIN • LOCKHEED MARTIN CORP • LOCKH...
# southwest_airlines                  SOUTHWEST AIRLINES • SOUTHWEST AIRLINES CO.
# wells_fargo_advisors          WELLS FARGO ADVISORS • WELLS FARGO ADVISORS LL...
# none                                                                       NONE
# nucor                                                 NUCOR • NUCOR CORPORATION
# wells_fargo                                                         WELLS FARGO
# me                                                                     ME • ME!
# united_airlines               UNITED  AIRLINES • UNITED AIRLINES • UNITED AI...
# at_t                                                                AT&T • AT@T
# donald_j_trump_for_president  DONALD J TRUMP FOR PRESIDENT • DONALD J TRUMP ...
# american_energy               AMERICAN ENERGY • AMERICAN ENERGY CORP • AMERI...
# google                        GOOGLE • GOOGLE INC • GOOGLE INC. • GOOGLE, IN...
# business_owner                                                   BUSINESS OWNER
# morgan_stanley                              MORGAN STANLEY • MORGAN STANLEY INC
# america_s_catch                                                 AMERICA'S CATCH
# twenty_one_twelve                                             TWENTY ONE TWELVE
# coldwell_banker                              COLDWELL  BANKER • COLDWELL BANKER
# cisco_systems                 CISCO SYSTEMS • CISCO SYSTEMS INC. • CISCO SYS...
# us_navy                                                                 US NAVY
# walmart                                           WALMART • WALMART CORPORATION
# bank_of_america                                                 BANK OF AMERICA
# usaf                                                                       USAF
# centaur_gaming                                                   CENTAUR GAMING
# boeing                        BOEING • BOEING CO • BOEING CO. • BOEING CORPO...
# usps                                                               USPS • USPS.
# veg_fresh_farms                           VEG FRESH FARMS • VEG FRESH FARMS LLC
# dod                                                                         DOD

# %% [markdown]
# ---
#
# ## Save results

# %%
decimalize = lambda x: float("{0:.2f}".format(x)) if isinstance(x, float) else x

# %%
tech_contributions.groupby([ "meta_employer", "contributor_employer"])["contribution_amount"].sum()\
    .apply(decimalize)\
    .to_csv("../output/raw-employer-names.csv")

# %%
tech_contributions.sort_values([
        "meta_employer", "contributor_employer",
        "contributor_last_name", "contributor_first_name", "contributor_middle_name",
        "contribution_date"
    ])\
    .applymap(decimalize)\
    .to_csv("../output/tech-contributions.csv", index=False)

# %%
tech_contributions_by_employer\
    .applymap(decimalize)\
    .to_csv("../output/tech-employer-totals.csv")

# %%
top_employers_clinton\
    .apply(decimalize)\
    .to_csv("../output/top-employers-clinton.csv")

# %%
top_employers_trump\
    .apply(decimalize)\
    .to_csv("../output/top-employers-trump.csv")

# %% [markdown]
# ---
#
# ---
#
# ---
